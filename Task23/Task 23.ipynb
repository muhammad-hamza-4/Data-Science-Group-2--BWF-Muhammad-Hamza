# %% [markdown]
# # Task 23
# Using Randim Data,fitting model and predicting results

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

model = LinearRegression()

model.fit(X, y)

print('Intercept:', model.intercept_)
print('Coefficient:', model.coef_[0])

X_new = np.array([[0], [2]])
y_pred = model.predict(X_new)

plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X_new, y_pred, color='red', label='Fitted line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression using scikit-learn')
plt.legend()
plt.show()

print('Predictions for new data:')
for i, x_new in enumerate(X_new):
    print(f'X = {x_new[0]} -> y_pred = {y_pred[i][0]}')
# Out:
# Intercept: [3.99789377]
# Coefficient: [2.97668002]
# Predictions for new data:
# X = 0 -> y_pred = 3.9978937718202787
# X = 2 -> y_pred = 9.951253804586235
