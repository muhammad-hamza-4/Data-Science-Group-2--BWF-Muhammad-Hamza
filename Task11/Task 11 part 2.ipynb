# %% [markdown]
# # Task 11 Part 2
# These Task have all random generated examples through numpy

# %%
import numpy as np


arr1 = np.random.randint(0, 10, (6, 6))
sub_arr1 = arr1[1:3, 1:3]


arr2 = np.random.randint(0, 10, (3, 2, 1))
sub_arr2 = arr2[:2, :, 1]


arr3 = np.array([1, 2, 3, 4, 5, 6, 7])
sub_arr3 = arr3[[1, 3, 4, 6]]


arr4 = np.random.randint(0, 10, (6, 6))
sub_arr4 = arr4[[0, 2, 2]][:, [1, 3]]


arr5 = np.random.randint(0, 15, 10)
sub_arr5 = arr5[arr5 > 8]


arr6 = np.random.randint(0, 20, (6, 6))
arr6[arr6 > 13] = 0


arr7_1 = np.random.randint(0, 10, (4, 3))
arr7_2 = np.array([1, 2, 3])
result7 = arr7_1 + arr7_2[:, np.newaxis]


arr8_1 = np.random.randint(0, 10, (3, 3))
arr8_2 = np.array([1, 2, 3])
result8 = arr8_1 * arr8_2


arr9_1 = np.random.randint(0, 10, (3, 1))
arr9_2 = np.random.randint(0, 10, (1, 4))
result9 = arr9_1 + arr9_2


arr10_1 = np.random.randint(0, 10, (2, 3, 4))
arr10_2 = np.random.randint(0, 10, (3, 4))
result10 = arr10_1 + arr10_2[np.newaxis, :, :]


arr11 = np.random.randint(0, 10, (6, 6))
sub_arr11 = arr11[::2, ::2]
arr11_result = sub_arr11 + np.array([1, 2, 3, 4, 5, 6])[:, np.newaxis]


arr12 = np.random.randint(0, 10, (3, 2, 1))
sub_arr12 = arr12[:, :, 0]
arr12_result = sub_arr12 - np.random.randint(0, 5, (3, 1))


arr13 = np.random.randint(0, 10, (6, 6))
diagonal_arr = np.diag(arr13)


arr14 = np.random.randint(0, 10, (6, 6))
reversed_arr = arr14[:, ::-1]


arr15 = np.random.randint(0, 10, (7, 6, 5))
sub_arr15 = arr15[:2, :3, :4]
arr15_result = sub_arr15 + np.array([1, 2, 3, 4])


arr16 = np.random.randint(0, 10, (5, 3))
arr16[:, -1] = arr16[:, :2].sum(axis=1)
